# %% [markdown]
# # Olympics & Its Evolution  - First Semester 2021
# ###  Prepared by Sujil Kumar K.M (D00242726)
# ##### Cross Module Project with Programming, Statistics & Research

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os,sys
from scipy import stats
import matplotlib.pyplot as plt
import statsmodels.api as sm
from bokeh.plotting import figure, output_file, show
import bokeh.io
from bokeh.models import ColumnDataSource
from bokeh.plotting import *
from statsmodels.formula.api import ols

olympics = pd.read_csv('E:/Research in Data/Assignments/Proposal/Olympics/data_2/athlete_events.csv')

olympics.head()
# Out:
#    ID.                     Na.me Sex.rio  A.ge  Heigh.t  Weig.ht  \
# 0    1                 A Dijiang       M  24.0    180.0     80.0
# 1    2                  A Lamusi       M  23.0    170.0     60.0
# 2    3       Gunnar Nielsen Aaby       M  24.0      NaN      NaN
# 3    4      Edgar Lindenau Aabye       M  34.0      NaN      NaN
# 4    5  Christine Jacoba Aaftink       F  21.0    185.0     82.0
#
#             Te am N OC       Ga.mes  Ye.ar  Season      Ci ty         Spor t  \
# 0           China  CHN  1992 Summer   1992  Summer  Barcelona     Basketball
# 1           China  CHN  2012 Summer   2012  Summer     London           Judo
# 2         Denmark  DEN  1920 Summer   1920  Summer  Antwerpen       Football
# 3  Denmark/Sweden  DEN  1900 Summer   1900  Summer      Paris     Tug-Of-War
# 4     Netherlands  NED  1988 Winter   1988  Winter    Calgary  Speed Skating
#
#                              Ev ent M edal
# 0       Basketball Men's Basketball    NaN
# 1      Judo Men's Extra-Lightweight    NaN
# 2           Football Men's Football    NaN
# 3       Tug-Of-War Men's Tug-Of-War   Gold
# 4  Speed Skating Women's 500 metres    NaN

# %%
olympics.describe()
# Out:
#                  ID.           A.ge        Heigh.t        Weig.ht  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                Ye.ar
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %%
olympics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   ID.      271116 non-null  int64
#  1   Na.me    271116 non-null  object
#  2   Sex.rio  271116 non-null  object
#  3   A.ge     261642 non-null  float64
#  4   Heigh.t  210945 non-null  float64
#  5   Weig.ht  208241 non-null  float64
#  6   Te am    271116 non-null  object
#  7   N OC     271116 non-null  object
#  8   Ga.mes   271116 non-null  object
#  9   Ye.ar    271116 non-null  int64
#  10  Season   271116 non-null  object
#  11  Ci ty    271116 non-null  object
#  12  Spor t   271116 non-null  object
#  13  Ev ent   271116 non-null  object
#  14  M edal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
index = olympics.index
number_of_rows = len(index)
print(number_of_rows)
# Out:
# 271116

# %%
duplicate = olympics[olympics.duplicated()]

# %%
duplicate.count()
# Out:
# ID.        1385
# Na.me      1385
# Sex.rio    1385
# A.ge       1226
# Heigh.t      28
# Weig.ht      37
# Te am      1385
# N OC       1385
# Ga.mes     1385
# Ye.ar      1385
# Season     1385
# Ci ty      1385
# Spor t     1385
# Ev ent     1385
# M edal       11
# dtype: int64

# %%
duplicate
# Out:
#            ID.                                Na.me Sex.rio  A.ge  Heigh.t  \
# 1252       704                   Dsir Antoine Acket       M  27.0      NaN
# 4282      2449               William Truman Aldrich       M  48.0      NaN
# 4283      2449               William Truman Aldrich       M  48.0      NaN
# 4862      2777               Hermann Reinhard Alker       M  43.0      NaN
# 4864      2777               Hermann Reinhard Alker       M  43.0      NaN
# ...        ...                                  ...     ...   ...      ...
# 269994  135072  Anna Katrina Zinkeisen (-Heseltine)       F  46.0      NaN
# 269995  135072  Anna Katrina Zinkeisen (-Heseltine)       F  46.0      NaN
# 269997  135072  Anna Katrina Zinkeisen (-Heseltine)       F  46.0      NaN
# 269999  135073   Doris Clare Zinkeisen (-Johnstone)       F  49.0      NaN
# 270200  135173                     Henri Achille Zo       M  58.0      NaN
#
#         Weig.ht          Te am N OC       Ga.mes  Ye.ar  Season        Ci ty  \
# 1252        NaN        Belgium  BEL  1932 Summer   1932  Summer  Los Angeles
# 4282        NaN  United States  USA  1928 Summer   1928  Summer    Amsterdam
# 4283        NaN  United States  USA  1928 Summer   1928  Summer    Amsterdam
# 4862        NaN        Germany  GER  1928 Summer   1928  Summer    Amsterdam
# 4864        NaN        Germany  GER  1928 Summer   1928  Summer    Amsterdam
# ...         ...            ...  ...          ...    ...     ...          ...
# 269994      NaN  Great Britain  GBR  1948 Summer   1948  Summer       London
# 269995      NaN  Great Britain  GBR  1948 Summer   1948  Summer       London
# 269997      NaN  Great Britain  GBR  1948 Summer   1948  Summer       London
# 269999      NaN  Great Britain  GBR  1948 Summer   1948  Summer       London
# 270200      NaN         France  FRA  1932 Summer   1932  Summer  Los Angeles
#
#                   Spor t                                             Ev ent  \
# 1252    Art Competitions     Art Competitions Mixed Painting, Unknown Event
# 4282    Art Competitions  Art Competitions Mixed Painting, Drawings And ...
# 4283    Art Competitions  Art Competitions Mixed Painting, Drawings And ...
# 4862    Art Competitions  Art Competitions Mixed Architecture, Designs F...
# 4864    Art Competitions  Art Competitions Mixed Architecture, Architect...
# ...                  ...                                                ...
# 269994  Art Competitions         Art Competitions Mixed Painting, Paintings
# 269995  Art Competitions         Art Competitions Mixed Painting, Paintings
# 269997  Art Competitions     Art Competitions Mixed Painting, Unknown Event
# 269999  Art Competitions     Art Competitions Mixed Painting, Unknown Event
# 270200  Art Competitions     Art Competitions Mixed Painting, Unknown Event
#
#        M edal
# 1252      NaN
# 4282      NaN
# 4283      NaN
# 4862      NaN
# 4864      NaN
# ...       ...
# 269994    NaN
# 269995    NaN
# 269997    NaN
# 269999    NaN
# 270200    NaN
#
# [1385 rows x 15 columns]

# %% [markdown]
# Above are the duplicated columns which we need to clean

# %%
olympics.drop_duplicates(subset = None ,keep = False, inplace = True)

# %%
olympics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 269119 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   ID.      269119 non-null  int64
#  1   Na.me    269119 non-null  object
#  2   Sex.rio  269119 non-null  object
#  3   A.ge     259896 non-null  float64
#  4   Heigh.t  210904 non-null  float64
#  5   Weig.ht  208196 non-null  float64
#  6   Te am    269119 non-null  object
#  7   N OC     269119 non-null  object
#  8   Ga.mes   269119 non-null  object
#  9   Ye.ar    269119 non-null  int64
#  10  Season   269119 non-null  object
#  11  Ci ty    269119 non-null  object
#  12  Spor t   269119 non-null  object
#  13  Ev ent   269119 non-null  object
#  14  M edal   39761 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 32.9+ MB

# %%
olympics
# Out:
#            ID.                     Na.me Sex.rio  A.ge  Heigh.t  Weig.ht  \
# 0            1                 A Dijiang       M  24.0    180.0     80.0
# 1            2                  A Lamusi       M  23.0    170.0     60.0
# 2            3       Gunnar Nielsen Aaby       M  24.0      NaN      NaN
# 3            4      Edgar Lindenau Aabye       M  34.0      NaN      NaN
# 4            5  Christine Jacoba Aaftink       F  21.0    185.0     82.0
# ...        ...                       ...     ...   ...      ...      ...
# 271111  135569                Andrzej ya       M  29.0    179.0     89.0
# 271112  135570                  Piotr ya       M  27.0    176.0     59.0
# 271113  135570                  Piotr ya       M  27.0    176.0     59.0
# 271114  135571        Tomasz Ireneusz ya       M  30.0    185.0     96.0
# 271115  135571        Tomasz Ireneusz ya       M  34.0    185.0     96.0
#
#                  Te am N OC       Ga.mes  Ye.ar  Season           Ci ty  \
# 0                China  CHN  1992 Summer   1992  Summer       Barcelona
# 1                China  CHN  2012 Summer   2012  Summer          London
# 2              Denmark  DEN  1920 Summer   1920  Summer       Antwerpen
# 3       Denmark/Sweden  DEN  1900 Summer   1900  Summer           Paris
# 4          Netherlands  NED  1988 Winter   1988  Winter         Calgary
# ...                ...  ...          ...    ...     ...             ...
# 271111        Poland-1  POL  1976 Winter   1976  Winter       Innsbruck
# 271112          Poland  POL  2014 Winter   2014  Winter           Sochi
# 271113          Poland  POL  2014 Winter   2014  Winter           Sochi
# 271114          Poland  POL  1998 Winter   1998  Winter          Nagano
# 271115          Poland  POL  2002 Winter   2002  Winter  Salt Lake City
#
#                Spor t                                    Ev ent M edal
# 0          Basketball               Basketball Men's Basketball    NaN
# 1                Judo              Judo Men's Extra-Lightweight    NaN
# 2            Football                   Football Men's Football    NaN
# 3          Tug-Of-War               Tug-Of-War Men's Tug-Of-War   Gold
# 4       Speed Skating          Speed Skating Women's 500 metres    NaN
# ...               ...                                       ...    ...
# 271111           Luge                Luge Mixed (Men)'s Doubles    NaN
# 271112    Ski Jumping  Ski Jumping Men's Large Hill, Individual    NaN
# 271113    Ski Jumping        Ski Jumping Men's Large Hill, Team    NaN
# 271114      Bobsleigh                      Bobsleigh Men's Four    NaN
# 271115      Bobsleigh                      Bobsleigh Men's Four    NaN
#
# [269119 rows x 15 columns]

# %%
olympics.duplicated().sum()
# Out:
# 0

# %%
index = olympics.index
number_of_rows = len(index)
print(number_of_rows)
# Out:
# 269119

# %% [markdown]
# Now we have cleaned all the duplicates from the dataset

# %% [markdown]
# ##### Renaming columns into meaningful ones

# %%
olympics.columns = olympics.columns.str.replace(' ','')
olympics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 269119 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   ID.      269119 non-null  int64
#  1   Na.me    269119 non-null  object
#  2   Sex.rio  269119 non-null  object
#  3   A.ge     259896 non-null  float64
#  4   Heigh.t  210904 non-null  float64
#  5   Weig.ht  208196 non-null  float64
#  6   Team     269119 non-null  object
#  7   NOC      269119 non-null  object
#  8   Ga.mes   269119 non-null  object
#  9   Ye.ar    269119 non-null  int64
#  10  Season   269119 non-null  object
#  11  City     269119 non-null  object
#  12  Sport    269119 non-null  object
#  13  Event    269119 non-null  object
#  14  Medal    39761 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 32.9+ MB

# %% [markdown]
# In above code removed spaces from columns

# %%
olympics.columns = olympics.columns.str.replace('.','')
olympics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 269119 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      269119 non-null  int64
#  1   Name    269119 non-null  object
#  2   Sexrio  269119 non-null  object
#  3   Age     259896 non-null  float64
#  4   Height  210904 non-null  float64
#  5   Weight  208196 non-null  float64
#  6   Team    269119 non-null  object
#  7   NOC     269119 non-null  object
#  8   Games   269119 non-null  object
#  9   Year    269119 non-null  int64
#  10  Season  269119 non-null  object
#  11  City    269119 non-null  object
#  12  Sport   269119 non-null  object
#  13  Event   269119 non-null  object
#  14  Medal   39761 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 32.9+ MB
# <ipython-input-14-7f8ee8154c45>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   olympics.columns = olympics.columns.str.replace('.','')

# %%
olympics.columns = map(str.lower, olympics.columns)
olympics.head()
# Out:
#    id                      name sexrio   age  height  weight            team  \
# 0   1                 A Dijiang      M  24.0   180.0    80.0           China
# 1   2                  A Lamusi      M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby      M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye      M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink      F  21.0   185.0    82.0     Netherlands
#
#    noc        games  year  season       city          sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               event medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %%
olympics.rename( {'sexrio':'sex' } , axis=1 , inplace = True)
olympics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 269119 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      269119 non-null  int64
#  1   name    269119 non-null  object
#  2   sex     269119 non-null  object
#  3   age     259896 non-null  float64
#  4   height  210904 non-null  float64
#  5   weight  208196 non-null  float64
#  6   team    269119 non-null  object
#  7   noc     269119 non-null  object
#  8   games   269119 non-null  object
#  9   year    269119 non-null  int64
#  10  season  269119 non-null  object
#  11  city    269119 non-null  object
#  12  sport   269119 non-null  object
#  13  event   269119 non-null  object
#  14  medal   39761 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 32.9+ MB

# %% [markdown]
# ### Loading Second Dataset

# %%
regions = pd.read_csv('E:/Research in Data/Assignments/Proposal/Olympics/data_2/noc_regions.csv')

regions.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
regions.columns = map(str.lower, regions.columns)
regions.head()
# Out:
#    noc       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %% [markdown]
# ##### Left Join  Merge of 2 DataFrames

# %%
data = pd.merge(olympics,regions, on=['noc'], how='left')

data.head(5)
# Out:
#    id                      name sex   age  height  weight            team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    noc        games  year  season       city          sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               event medal       region notes
# 0       Basketball Men's Basketball   NaN        China   NaN
# 1      Judo Men's Extra-Lightweight   NaN        China   NaN
# 2           Football Men's Football   NaN      Denmark   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold      Denmark   NaN
# 4  Speed Skating Women's 500 metres   NaN  Netherlands   NaN

# %%
data.sort_values(by=['year'], inplace=True, ascending=False)
data.head()
# Out:
#            id                              name sex   age  height  weight  \
# 194731  98525          Maksim Sergeyevich Rakov   M  30.0   181.0   100.0
# 162035  82008  Alexandra Patricia "Alex" Morgan   F  27.0   173.0    62.0
# 117646  59981                    Kim Hyeon-Seop   M  31.0   175.0    53.0
# 117647  59981                    Kim Hyeon-Seop   M  31.0   175.0    53.0
# 38150   19756                         Chang Hao   M  25.0   173.0    72.0
#
#                   team  noc        games  year  season            city  \
# 194731      Kazakhstan  KAZ  2016 Summer  2016  Summer  Rio de Janeiro
# 162035   United States  USA  2016 Summer  2016  Summer  Rio de Janeiro
# 117646     South Korea  KOR  2016 Summer  2016  Summer  Rio de Janeiro
# 117647     South Korea  KOR  2016 Summer  2016  Summer  Rio de Janeiro
# 38150   Chinese Taipei  TPE  2016 Summer  2016  Summer  Rio de Janeiro
#
#             sport                               event medal       region notes
# 194731       Judo         Judo Men's Half-Heavyweight   NaN   Kazakhstan   NaN
# 162035   Football           Football Women's Football   NaN          USA   NaN
# 117646  Athletics  Athletics Men's 20 kilometres Walk   NaN  South Korea   NaN
# 117647  Athletics  Athletics Men's 50 kilometres Walk   NaN  South Korea   NaN
# 38150     Sailing            Sailing Men's Windsurfer   NaN       Taiwan   NaN

# %%
#data = data[data['year'].between(1964, 2015)] - This code is used to only exact 50 Years .... currently I am planning to analyze entire dataset I have recieved

# %% [markdown]
# ##### Search for null values

# %%
data.isnull().sum().sum()
# Out:
# 622177

# %%
data.isnull().sum()
# Out:
# id             0
# name           0
# sex            0
# age         9223
# height     58215
# weight     60923
# team           0
# noc            0
# games          0
# year           0
# season         0
# city           0
# sport          0
# event          0
# medal     229358
# region       370
# notes     264088
# dtype: int64

# %%
data.isnull().sum()
# Out:
# id             0
# name           0
# sex            0
# age         9223
# height     58215
# weight     60923
# team           0
# noc            0
# games          0
# year           0
# season         0
# city           0
# sport          0
# event          0
# medal     229358
# region       370
# notes     264088
# dtype: int64

# %% [markdown]
# ##### Correcting Variable's Data Dype

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 269119 entries, 194731 to 69539
# Data columns (total 17 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      269119 non-null  int64
#  1   name    269119 non-null  object
#  2   sex     269119 non-null  object
#  3   age     259896 non-null  float64
#  4   height  210904 non-null  float64
#  5   weight  208196 non-null  float64
#  6   team    269119 non-null  object
#  7   noc     269119 non-null  object
#  8   games   269119 non-null  object
#  9   year    269119 non-null  int64
#  10  season  269119 non-null  object
#  11  city    269119 non-null  object
#  12  sport   269119 non-null  object
#  13  event   269119 non-null  object
#  14  medal   39761 non-null   object
#  15  region  268749 non-null  object
#  16  notes   5031 non-null    object
# dtypes: float64(3), int64(2), object(12)
# memory usage: 37.0+ MB

# %%
#data.weight.duplicated().sum()
data['weight'].isnull().sum()

data['weight'].isnull().sum()
# Out:
# 60923

# %%
data['weight'].unique()
# Out:
# array([100.        ,  62.        ,  53.        ,  72.        ,
#         98.        ,  50.        ,  80.        ,  45.        ,
#         60.        ,  52.        ,  95.        ,  48.        ,
#         61.        ,  92.        ,  63.        ,  59.        ,
#         76.        , 125.        ,  77.        ,  78.        ,
#         54.        ,  73.        ,  42.        ,  70.        ,
#         82.        ,  90.        ,  75.        ,  65.        ,
#        105.        ,  56.        ,  58.        ,  86.        ,
#         34.        ,  91.        ,  57.        ,  67.        ,
#         68.        ,  71.        ,  55.        ,  66.        ,
#         64.        ,  69.        ,  87.        , 143.        ,
#         74.        ,  49.        , 108.        ,          nan,
#         88.        ,  79.        ,  85.        ,  94.        ,
#         84.        ,  83.        , 118.        ,  99.        ,
#         93.        , 107.        ,  51.        , 104.        ,
#         39.        ,  44.        ,  46.        ,  97.        ,
#         40.        , 110.        ,  81.        , 130.        ,
#        103.        ,  47.        ,  96.        , 120.        ,
#        101.        , 155.        , 109.        , 102.        ,
#        123.        ,  43.        , 124.        ,  89.        ,
#        115.        , 140.        ,  41.        , 135.        ,
#        112.        , 136.        , 150.        , 127.        ,
#        113.        , 106.        , 117.        , 170.        ,
#        111.        , 114.        , 122.        , 152.        ,
#        160.        , 116.        ,  38.        ,  35.        ,
#        142.        ,  37.        , 119.        , 132.        ,
#        134.        ,  30.        ,  36.        , 158.        ,
#        126.        , 138.        , 128.        , 148.        ,
#        141.        , 139.        , 146.        , 147.        ,
#        133.        ,  33.        , 137.        , 144.        ,
#        121.        ,  31.        , 145.        , 165.        ,
#         69.5       , 118.5       ,  55.5       , 154.        ,
#         79.5       ,  56.5       ,  64.5       , 103.5       ,
#        129.        , 101.5       , 214.        , 102.5       ,
#        156.        ,  97.5       ,  65.5       , 131.        ,
#         70.5       ,  88.5       ,  81.5       ,  32.        ,
#         52.5       ,  90.5       , 131.5       , 167.        ,
#         85.5       , 109.5       , 151.        , 121.5       ,
#        117.5       , 163.        , 133.5       ,  28.        ,
#         72.5       ,  87.5       , 161.        , 175.        ,
#        104.5       , 137.5       ,  54.5       ,  76.5       ,
#         67.5       ,  74.5       ,  98.5       , 198.        ,
#        178.        ,  77.5       ,  71.5       ,  68.5       ,
#        138.5       ,  61.5       ,  75.5       ,  80.5       ,
#        100.5       ,  63.5       ,  60.5       , 180.        ,
#         91.5       ,  48.5       ,  78.5       , 129.5       ,
#         66.5       ,  82.5       ,  77.33333333,  73.5       ,
#         86.5       ,  93.5       , 149.        ,  89.5       ,
#        108.5       , 107.5       , 127.5       , 176.5       ,
#         96.5       ,  62.5       ,  57.5       ,  84.5       ,
#         49.5       ,  92.5       , 112.5       ,  83.5       ,
#        135.5       ,  74.66666667,  25.        , 190.        ,
#        122.5       ,  53.5       ,  59.5       ,  51.5       ,
#        146.5       ,  58.5       , 182.        , 105.5       ,
#        106.5       , 130.5       , 116.5       , 123.5       ,
#         95.5       ])

# %%
data['sex'] = data['sex'].astype('category')
data['year'] = data['year'].astype('int')
data['team'] = data['team'].astype('category')
data['season'] = data['season'].astype('category')
data['weight'] = data['weight'].astype('float')
data['height'] = data['height'].astype('float')
data['name'] = data['name'].astype('str')
data['noc'] = data['noc'].astype('category')
data['city'] = data['city'].astype('str')
data['sport'] = data['sport'].astype('str')
data['event'] = data['event'].astype('category')
data['medal'] = data['medal'].astype('category')
data['games'] = data['games'].astype('category')

# %%
data.dtypes
# Out:
# id           int64
# name        object
# sex       category
# age        float64
# height     float64
# weight     float64
# team      category
# noc       category
# games     category
# year         int32
# season    category
# city        object
# sport       object
# event     category
# medal     category
# region      object
# notes       object
# dtype: object

# %% [markdown]
# ##### Check for Category Variable Uniqueness

# %%
data['sex'].unique()
# Out:
# ['M', 'F']
# Categories (2, object): ['M', 'F']

# %%
data['noc'].unique()
# Out:
# ['KAZ', 'USA', 'KOR', 'TPE', 'RUS', ..., 'BOH', 'ANZ', 'UNK', 'CRT', 'NFL']
# Length: 230
# Categories (230, object): ['KAZ', 'USA', 'KOR', 'TPE', ..., 'ANZ', 'UNK', 'CRT', 'NFL']

# %%
data['games'].unique()
# Out:
# ['2016 Summer', '2014 Winter', '2012 Summer', '2010 Winter', '2008 Summer', ..., '1908 Summer', '1906 Summer', '1904 Summer', '1900 Summer', '1896 Summer']
# Length: 51
# Categories (51, object): ['2016 Summer', '2014 Winter', '2012 Summer', '2010 Winter', ..., '1906 Summer', '1904 Summer', '1900 Summer', '1896 Summer']

# %%
data['season'].unique()
# Out:
# ['Summer', 'Winter']
# Categories (2, object): ['Summer', 'Winter']

# %%
data['sport'].unique()
# Out:
# array(['Judo', 'Football', 'Athletics', 'Sailing', 'Rowing', 'Archery',
#        'Wrestling', 'Gymnastics', 'Cycling', 'Fencing', 'Swimming',
#        'Badminton', 'Hockey', 'Table Tennis', 'Shooting', 'Boxing',
#        'Volleyball', 'Taekwondo', 'Rhythmic Gymnastics', 'Golf',
#        'Weightlifting', 'Handball', 'Tennis', 'Water Polo',
#        'Modern Pentathlon', 'Rugby Sevens', 'Canoeing', 'Triathlon',
#        'Equestrianism', 'Synchronized Swimming', 'Diving', 'Basketball',
#        'Beach Volleyball', 'Trampolining', 'Cross Country Skiing',
#        'Biathlon', 'Alpine Skiing', 'Figure Skating', 'Freestyle Skiing',
#        'Ice Hockey', 'Ski Jumping', 'Speed Skating', 'Bobsleigh',
#        'Nordic Combined', 'Snowboarding', 'Short Track Speed Skating',
#        'Luge', 'Skeleton', 'Curling', 'Baseball', 'Softball',
#        'Art Competitions', 'Polo', 'Aeronautics', 'Alpinism',
#        'Military Ski Patrol', 'Rugby', 'Tug-Of-War', 'Lacrosse',
#        'Jeu De Paume', 'Racquets', 'Motorboating', 'Roque', 'Cricket',
#        'Croquet', 'Basque Pelota'], dtype=object)

# %%
data['event'].unique()
# Out:
# ['Judo Men's Half-Heavyweight', 'Football Women's Football', 'Athletics Men's 20 kilometres Walk', 'Athletics Men's 50 kilometres Walk', 'Sailing Men's Windsurfer', ..., 'Gymnastics Men's Horizontal Bar, Teams', 'Shooting Men's Free Pistol, 30 metres', 'Swimming Men's 1,200 metres Freestyle', 'Swimming Men's 500 metres Freestyle', 'Wrestling Men's Unlimited Class, Greco-Roman']
# Length: 765
# Categories (765, object): ['Judo Men's Half-Heavyweight', 'Football Women's Football', 'Athletics Men's 20 kilometres Walk', 'Athletics Men's 50 kilometres Walk', ..., 'Shooting Men's Free Pistol, 30 metres', 'Swimming Men's 1,200 metres Freestyle', 'Swimming Men's 500 metres Freestyle', 'Wrestling Men's Unlimited Class, Greco-Roman']

# %%
data['medal'].unique()
# Out:
# [NaN, 'Gold', 'Bronze', 'Silver']
# Categories (3, object): ['Gold', 'Bronze', 'Silver']

# %%
data['team'].unique()
# Out:
# ['Kazakhstan', 'United States', 'South Korea', 'Chinese Taipei', 'Russia', ..., 'Crocodile-13', 'Fantlet-2', 'Ethnikos Gymnastikos Syllogos', 'Great Britain/Germany', 'Australia/Great Britain']
# Length: 1164
# Categories (1164, object): ['Kazakhstan', 'United States', 'South Korea', 'Chinese Taipei', ..., 'Fantlet-2', 'Ethnikos Gymnastikos Syllogos', 'Great Britain/Germany', 'Australia/Great Britain']

# %% [markdown]
# Above values seems to be ok , there is no need to modify or remove any values as part of cleaning

# %% [markdown]
# #### Dealing with Empty Columns & Outliers in the dataset

# %%
data['id'].count()
# Out:
# 269119

# %%
data.isnull().sum(axis = 0)
# Out:
# id             0
# name           0
# sex            0
# age         9223
# height     58215
# weight     60923
# team           0
# noc            0
# games          0
# year           0
# season         0
# city           0
# sport          0
# event          0
# medal     229358
# region       370
# notes     264088
# dtype: int64

# %% [markdown]
# Below is percentage of NaN values for each columns

# %%
nans = data.isna().mean().mul(100).round()
nans
# Out:
# id         0.0
# name       0.0
# sex        0.0
# age        3.0
# height    22.0
# weight    23.0
# team       0.0
# noc        0.0
# games      0.0
# year       0.0
# season     0.0
# city       0.0
# sport      0.0
# event      0.0
# medal     85.0
# region     0.0
# notes     98.0
# dtype: float64

# %% [markdown]
# <div style="color:#102547; background-color:powderblue;">Age : Checking the empty values in the column it's only 3.42% of total rows so , I am not going to replace them with mean or median.
#
# Height : 22% of total rows shows empty values. so I neeed to either drop them or replace with mean/median
#
# Weight : 23% of total rows shows empty values. Again I neeed to either drop them or replace with mean/median
#
# Theoretically, 25% to 30% is the maximum missing values allowed, beyond that we might want to drop the variable from analysis. In practical this may very based on client requirements.In this case I am doing Imputation for missing data. but before deciding on use mean or median I need to check if the data is skewed or not. If it is symmetrical it's appropriate to use mean. In skwed case using median will the best solution. Let me have a look at the boxplot before moving forward.
#
# </div>

# %%
sns.boxplot(y='age', data=data)
plt.show()

# %% [markdown]
# From the above graph I can see the age is showing between 20 to 100. even though few points near hundred seems like outliers, still we can not remove them as these are possible values for a human age

# %%
sns.boxplot(y='height', data=data)
plt.show()

# %% [markdown]
# Above graph points doesn't looks like outliers, the points showing only possible outcomes, further study is required to make more clarity

# %%
sns.boxplot(y='weight', data=data)
plt.show()

# %% [markdown]
# Above graph points doesn't looks like outliers, the points showing are still possible outcomes, further study is required to make more clarity

# %% [markdown]
# <div style="color:#102547; background-color:powderblue;">
#     <h4 style="color:##875218;"><u>Overview</u></h4><p>
#     In my view I looked at 3 Graphs for replacing empty columns with mean/median. and here are my findings.<ul>
# <li>Age : Data looks skewed so I have replace it with median</li>
# <li>Height : Looks symmetrical, it is ok to replace them with the mean</li>
# <li>Weight : Data looks skewed so I have replace it with median</li>
# </ul>
#
#  </p></div>

# %% [markdown]
# ##### Replacing NaN values with mean/median

# %%
data.update(data['age'].fillna(value=data['age'].median(), inplace=True))

# %%
data.update(data['height'].fillna(value=data['height'].mean(), inplace=True))

# %%
data.update(data['weight'].fillna(value=data['weight'].mean(), inplace=True))

# %%
data['age'].isnull().sum()
# Out:
# 0

# %%
data['height'].isnull().sum()
# Out:
# 0

# %%
data['weight'].isnull().sum()
# Out:
# 0

# %%
data['medal'].value_counts().sum()
# Out:
# 39761

# %% [markdown]
# No need to worry about the medals for now, because it will show values for only those who won the competetion.

# %%
data['region'].value_counts().sum()
# Out:
# 268749

# %% [markdown]
# Region has only 0.13% of empty data which doesn't really affect the study compared to the total data we have.

# %% [markdown]
# Data Cleaning has been completed

# %% [markdown]
# ### Distribution of the age of winning gold medals

# %%
gold_medalists = data[(data.medal == 'Gold')]
gold_medalists.head()
# Out:
#             id                    name sex   age  height  weight         team  \
# 38164    19760           Chang Hye-Jin   F  29.0   158.0    50.0  South Korea
# 38165    19760           Chang Hye-Jin   F  29.0   158.0    50.0  South Korea
# 10150     5561         Nickel Ashmeade   M  26.0   183.0    77.0      Jamaica
# 242984  122548  Josua Tuisova Ratulevu   M  22.0   180.0   108.0         Fiji
# 243000  122556              Blair Tuke   M  27.0   181.0    78.0  New Zealand
#
#         noc        games  year  season            city         sport  \
# 38164   KOR  2016 Summer  2016  Summer  Rio de Janeiro       Archery
# 38165   KOR  2016 Summer  2016  Summer  Rio de Janeiro       Archery
# 10150   JAM  2016 Summer  2016  Summer  Rio de Janeiro     Athletics
# 242984  FIJ  2016 Summer  2016  Summer  Rio de Janeiro  Rugby Sevens
# 243000  NZL  2016 Summer  2016  Summer  Rio de Janeiro       Sailing
#
#                                        event medal       region notes
# 38164             Archery Women's Individual  Gold  South Korea   NaN
# 38165                   Archery Women's Team  Gold  South Korea   NaN
# 10150   Athletics Men's 4 x 100 metres Relay  Gold      Jamaica   NaN
# 242984       Rugby Sevens Men's Rugby Sevens  Gold         Fiji   NaN
# 243000                   Sailing Men's Skiff  Gold  New Zealand   NaN

# %% [markdown]
# #### Exporting data for API Creation

# %%
data.to_csv('E:/Research in Data/Assignments/Proposal/Olympics/data_2/api_dataset.csv')

# %% [markdown]
# ## Describe Variables

# %% [markdown]
# id = continueous Variables - Stands for each id of athlete
#
# name = categorical - nominal - name of athletes
#
# age = continueous numeric - age of athlete
#
# height = continueous numeric - height of athlete in cm
#
# weight = continueous numeric - weight of athlete in kg
#
# sex = categorical , norminal - male/female info about athlete
#
# team = categorical , norminal - name of the team athlete represent
#
# noc = categorical , norminal - short name of the team athlete represent
#
# games = categorical , norminal - Year and season of the game
#
# year = continueous numeric - Year of the event
#
# season = categorical , norminal - Summer/winter seaons of olympic games
#
# city = categorical , norminal - name of the city olympics conducted
#
# sport = categorical , norminal - which sports item the athlete participated
#
# event = categorical , norminal - name of the sports in detail format
#
# medal = categorical , ordinal - gold/silver/bronze medals for the athelete, empty if no medal
#
# region = categorical , norminal - regios is same as the team

# %% [markdown]
# Above code creates a dataframe only for Gold Medalists

# %%
gold_medalists['age'].isnull().any()
# Out:
# False

# %%
gold_medalists = gold_medalists[np.isfinite(gold_medalists['age'])]

# %%
gold_medalists['age'].isnull().any()
# Out:
# False

# %% [markdown]
# I am avoiding NaN values from the gold winners dataset as they will be affecting the mean and median of the varibales.(Another chance was to fill them with zero'z or replace with mean or median both of them seems to be unjustifiable)

# %%
plt.figure(figsize=(18, 10))
plt.xticks(rotation = 60)
plt.tight_layout()
sns.countplot(gold_medalists['age'])
plt.title('Distribution of Gold Medals')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Distribution of Gold Medals')

# %% [markdown]
# Above graph is slightly skewed to the right. Median might be lying between 23 to 24. But since this is skewed mean might very

# %% [markdown]
# ##### So let's try to check now medal winning of athletes whose age are more than 50

# %% [markdown]
# That's seems intresting !, there are 201 athletes who won medan aged more than 50

# %% [markdown]
# I am gonna create a new Dataframe called master_medalists with these 201 people and try to visualize it

# %%
master_medalists = gold_medalists['sport'][gold_medalists['age'] > 50]

# %%
master_medalists.count()
# Out:
# 65

# %%
plt.figure(figsize=(20, 10))
plt.xticks(rotation = 60)
plt.tight_layout()
sns.countplot(master_medalists)
plt.title('Medals for Athletes Over 50')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Medals for Athletes Over 50')

# %% [markdown]
# It Seems our senior gold medalists are from shooters, archers, sailors and, above all, horse riders(Equestrianism) !

# %% [markdown]
# <h3 style="color: #e61968;">Overview into Women Athletes Contributions</h3>

# %%
women_summer = data[(data.sex == 'F') & (data.season == 'Summer')]
women_summer.head()
# Out:
#            id                              name sex   age  height  weight  \
# 162035  82008  Alexandra Patricia "Alex" Morgan   F  27.0   173.0    62.0
# 38164   19760                     Chang Hye-Jin   F  29.0   158.0    50.0
# 38165   19760                     Chang Hye-Jin   F  29.0   158.0    50.0
# 161905  81946        Alexa Citiali Moreo Medina   F  21.0   147.0    45.0
# 161904  81946        Alexa Citiali Moreo Medina   F  21.0   147.0    45.0
#
#                  team  noc        games  year  season            city  \
# 162035  United States  USA  2016 Summer  2016  Summer  Rio de Janeiro
# 38164     South Korea  KOR  2016 Summer  2016  Summer  Rio de Janeiro
# 38165     South Korea  KOR  2016 Summer  2016  Summer  Rio de Janeiro
# 161905         Mexico  MEX  2016 Summer  2016  Summer  Rio de Janeiro
# 161904         Mexico  MEX  2016 Summer  2016  Summer  Rio de Janeiro
#
#              sport                            event medal       region notes
# 162035    Football        Football Women's Football   NaN          USA   NaN
# 38164      Archery       Archery Women's Individual  Gold  South Korea   NaN
# 38165      Archery             Archery Women's Team  Gold  South Korea   NaN
# 161905  Gymnastics  Gymnastics Women's Balance Beam   NaN       Mexico   NaN
# 161904  Gymnastics   Gymnastics Women's Uneven Bars   NaN       Mexico   NaN

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(20, 10))
sns.countplot(x='year', data=women_summer)
plt.title('Women participation per year of the Games')
# Out:
# Text(0.5, 1.0, 'Women participation per year of the Games')

# %% [markdown]
# <p style="color: #e61968;">Above diagram shows a women participation has increased over time in summer olympics</p>

# %%
women_winter = data[(data.sex == 'F') & (data.season == 'Winter')]
women_winter.head()
# Out:
#             id                           name sex   age  height  weight  \
# 224004  113417  Gabriela Soukalov (-Koukalov)   F  24.0   170.0    62.0
# 43100    22368              Alexandra Coletti   F  30.0   164.0    60.0
# 44002    22848                     Emily Cook   F  34.0   160.0    52.0
# 44126    22911              Penny Jane Coomes   F  24.0   152.0    43.0
# 191963   97106                Alena Prochzkov   F  29.0   171.0    55.0
#
#                   team  noc        games  year  season   city  \
# 224004  Czech Republic  CZE  2014 Winter  2014  Winter  Sochi
# 43100           Monaco  MON  2014 Winter  2014  Winter  Sochi
# 44002    United States  USA  2014 Winter  2014  Winter  Sochi
# 44126    Great Britain  GBR  2014 Winter  2014  Winter  Sochi
# 191963        Slovakia  SVK  2014 Winter  2014  Winter  Sochi
#
#                        sport                                        event  \
# 224004              Biathlon  Biathlon Women's 12.5 kilometres Mass Start
# 43100          Alpine Skiing               Alpine Skiing Women's Combined
# 44002       Freestyle Skiing             Freestyle Skiing Women's Aerials
# 44126         Figure Skating             Figure Skating Mixed Ice Dancing
# 191963  Cross Country Skiing   Cross Country Skiing Women's 10 kilometres
#
#          medal          region notes
# 224004  Silver  Czech Republic   NaN
# 43100      NaN          Monaco   NaN
# 44002      NaN             USA   NaN
# 44126      NaN              UK   NaN
# 191963     NaN        Slovakia   NaN

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(20, 10))
sns.countplot(x='year', data=women_winter)
plt.title('Women participation per year of the Winter Games')
# Out:
# Text(0.5, 1.0, 'Women participation per year of the Winter Games')

# %% [markdown]
# <p style="color: #e61968;">Above diagram shows a women participation has increased over time in winter olympics as well</p>

# %% [markdown]
# Inroder to cross check the above diagram I am just displaying the dataframe again down for year 1956 Year

# %%
women_winter = data[(data.year == 1956) & (data.medal == 'Gold') & (data.sex == 'F') & (data.id == 2386)]
women_winter
# Out:
#         id                                        name sex   age      height  \
# 4155  2386  Tenley Emma Albright (-Gardiner, -Blakely)   F  20.0  175.338941
#
#          weight           team  noc        games  year  season  \
# 4155  70.701618  United States  USA  1956 Winter  1956  Winter
#
#                    city           sport                           event medal  \
# 4155  Cortina d'Ampezzo  Figure Skating  Figure Skating Women's Singles  Gold
#
#      region notes
# 4155    USA   NaN

# %% [markdown]
# Again to match with the diagram and cross check just taking the count

# %%
women_winter['id'].loc[women_winter['year'] == 1956].count()
# Out:
# 1

# %% [markdown]
# Now it's clearly visible that 246 is matching the count plot year of 1956 , Even I have verified the data in Wikipedia to make sure my research is going in the right direction

# %% [markdown]
# ### Medals Achieved by each country

# %% [markdown]
# Checking which are the top countries leading with gold medals

# %%
gold_medalists.region.value_counts().reset_index(name='Medals').head(5)
# Out:
#      index  Medals
# 0      USA    2638
# 1   Russia    1599
# 2  Germany    1301
# 3       UK     676
# 4    Italy     575

# %% [markdown]
# Now I am going to visualize the results in graph

# %%
totalGoldMedals = gold_medalists.region.value_counts().reset_index(name='medal').head(5)
g = sns.catplot(x="index", y="medal", data=totalGoldMedals,
                height=6, kind="bar", palette="muted")
g.despine(left=True)
g.set_xlabels("Top 5 Countries")
g.set_ylabels("Number of Medals")
plt.title('Olympic Medals of Countries')
# Out:
# Text(0.5, 1.0, 'Olympic Medals of Countries')

# %% [markdown]
# USA Seems to have most number of gold medals compared to other countries

# %% [markdown]
# ### Disciplines with greatest number of Gold Medals

# %% [markdown]
# Creating a dataframe for showing USA Gold medal disciplines

# %%
us_gld_mdls = gold_medalists.loc[gold_medalists['noc'] == 'USA']

# %%
us_gld_mdls.event.value_counts().reset_index(name='medal').head(20)
# Out:
#                                               index  medal
# 0                       Basketball Men's Basketball    186
# 1     Swimming Men's 4 x 200 metres Freestyle Relay    111
# 2                         Rowing Men's Coxed Eights    108
# 3        Swimming Men's 4 x 100 metres Medley Relay    108
# 4                     Basketball Women's Basketball     95
# 5              Athletics Men's 4 x 400 metres Relay     81
# 6      Swimming Women's 4 x 100 metres Medley Relay     79
# 7   Swimming Women's 4 x 100 metres Freestyle Relay     78
# 8                         Football Women's Football     66
# 9              Athletics Men's 4 x 100 metres Relay     63
# 10    Swimming Men's 4 x 100 metres Freestyle Relay     58
# 11           Athletics Women's 4 x 100 metres Relay     50
# 12                        Softball Women's Softball     45
# 13           Athletics Women's 4 x 400 metres Relay     38
# 14                      Rowing Women's Coxed Eights     36
# 15                      Volleyball Men's Volleyball     36
# 16                      Ice Hockey Men's Ice Hockey     36
# 17                                Rugby Men's Rugby     36
# 18  Swimming Women's 4 x 200 metres Freestyle Relay     33
# 19                    Water Polo Women's Water Polo     25

# %% [markdown]
# I can see Basketball is the US's most won discipline, In this study we need to more focus on the individual persons charecterstics rather than the team, so we will check success of male athletes to better review it.
#
# I am creating a new dataframe to have more deeper look into the gold winning og USA Male Athletes Basketball Gold Medal Winning

# %%
basket_us_gld_mdls = us_gld_mdls.loc[(us_gld_mdls['sport'] == 'Basketball') & (us_gld_mdls['sex'] == 'M')].sort_values(['year'])

# %%
basket_us_gld_mdls.head(15)
# Out:
#             id                                  name sex   age  height  \
# 194273   98309               Jack Williamson Ragland   M  22.0   183.0
# 22247    11790                  Ralph English Bishop   M  20.0   193.0
# 211772  107150              Willard Theodore Schmidt   M  26.0   205.0
# 160458   81220             Arthur Owen "Art" Mollner   M  23.0   183.0
# 257597  129925          William John "Bill" Wheatley   M  27.0   188.0
# 108633   55375                   Francis Lee Johnson   M  25.0   180.0
# 142260   71965                      Frank John Lubin   M  26.0   200.0
# 187885   95095             Donald Arthur "Don" Piper   M  25.0   180.0
# 70856    36368       Joseph Cephis "Joe" Fortenberry   M  25.0   203.0
# 78419    40143            John Haskell "Tex" Gibbons   M  28.0   185.0
# 13614     7396           Samuel J. "Sam" Balter, Jr.   M  26.0   178.0
# 231688  117072               Duane Alexander Swanson   M  22.0   188.0
# 217568  110112                       Carl Leslie Shy   M  27.0   183.0
# 120814   61570                  Carl Stanley Knowles   M  26.0   188.0
# 200428  101443  Robert Lloyd Jackson "Jack" Robinson   M  21.0   183.0
#
#         weight           team  noc        games  year  season    city  \
# 194273    79.0  United States  USA  1936 Summer  1936  Summer  Berlin
# 22247     86.0  United States  USA  1936 Summer  1936  Summer  Berlin
# 211772    86.0  United States  USA  1936 Summer  1936  Summer  Berlin
# 160458    73.0  United States  USA  1936 Summer  1936  Summer  Berlin
# 257597    79.0  United States  USA  1936 Summer  1936  Summer  Berlin
# 108633    79.0  United States  USA  1936 Summer  1936  Summer  Berlin
# 142260   113.0  United States  USA  1936 Summer  1936  Summer  Berlin
# 187885    73.0  United States  USA  1936 Summer  1936  Summer  Berlin
# 70856     84.0  United States  USA  1936 Summer  1936  Summer  Berlin
# 78419     79.0  United States  USA  1936 Summer  1936  Summer  Berlin
# 13614     68.0  United States  USA  1936 Summer  1936  Summer  Berlin
# 231688    79.0  United States  USA  1936 Summer  1936  Summer  Berlin
# 217568    77.0  United States  USA  1936 Summer  1936  Summer  Berlin
# 120814    75.0  United States  USA  1936 Summer  1936  Summer  Berlin
# 200428    82.0  United States  USA  1948 Summer  1948  Summer  London
#
#              sport                        event medal region notes
# 194273  Basketball  Basketball Men's Basketball  Gold    USA   NaN
# 22247   Basketball  Basketball Men's Basketball  Gold    USA   NaN
# 211772  Basketball  Basketball Men's Basketball  Gold    USA   NaN
# 160458  Basketball  Basketball Men's Basketball  Gold    USA   NaN
# 257597  Basketball  Basketball Men's Basketball  Gold    USA   NaN
# 108633  Basketball  Basketball Men's Basketball  Gold    USA   NaN
# 142260  Basketball  Basketball Men's Basketball  Gold    USA   NaN
# 187885  Basketball  Basketball Men's Basketball  Gold    USA   NaN
# 70856   Basketball  Basketball Men's Basketball  Gold    USA   NaN
# 78419   Basketball  Basketball Men's Basketball  Gold    USA   NaN
# 13614   Basketball  Basketball Men's Basketball  Gold    USA   NaN
# 231688  Basketball  Basketball Men's Basketball  Gold    USA   NaN
# 217568  Basketball  Basketball Men's Basketball  Gold    USA   NaN
# 120814  Basketball  Basketball Men's Basketball  Gold    USA   NaN
# 200428  Basketball  Basketball Men's Basketball  Gold    USA   NaN

# %% [markdown]
# What I suspected was true, I was actually getting the count of team, as we know there are multiple players involved in a basketball team. Now I need to group the data based on year again to check the first record for each member of team

# %%
bskt_fnl_us = basket_us_gld_mdls.groupby(['year']).first()
bskt_fnl_us.head(5)
# Out:
#           id                                  name sex   age  height  weight  \
# year
# 1936   98309               Jack Williamson Ragland   M  22.0   183.0    79.0
# 1948  101443  Robert Lloyd Jackson "Jack" Robinson   M  21.0   183.0    82.0
# 1952  130602          Howard Earl "Howie" Williams   M  24.0   183.0    76.0
# 1956   17312                       Carl Cecil Cain   M  22.0   190.0    86.0
# 1960    9670      Walter Jones "Walt" Bellamy, Jr.   M  23.0   211.0    98.0
#
#                team  noc        games  season       city       sport  \
# year
# 1936  United States  USA  1936 Summer  Summer     Berlin  Basketball
# 1948  United States  USA  1948 Summer  Summer     London  Basketball
# 1952  United States  USA  1952 Summer  Summer   Helsinki  Basketball
# 1956  United States  USA  1956 Summer  Summer  Melbourne  Basketball
# 1960  United States  USA  1960 Summer  Summer       Roma  Basketball
#
#                             event medal region notes
# year
# 1936  Basketball Men's Basketball  Gold    USA  None
# 1948  Basketball Men's Basketball  Gold    USA  None
# 1952  Basketball Men's Basketball  Gold    USA  None
# 1956  Basketball Men's Basketball  Gold    USA  None
# 1960  Basketball Men's Basketball  Gold    USA  None

# %% [markdown]
# Now the data looks more accurate, Let me count the number of record now

# %%
bskt_fnl_us['id'].count()
# Out:
# 15

# %% [markdown]
# So we have recieved required results from the above, also confirmed with [Wikipedia](https://en.wikipedia.org/wiki/United_States_men%27s_national_basketball_team)

# %% [markdown]
# ### Median Height & Weight of Olympics Medalists

# %%
gold_medalists.head()
# Out:
#             id                    name sex   age  height  weight         team  \
# 38164    19760           Chang Hye-Jin   F  29.0   158.0    50.0  South Korea
# 38165    19760           Chang Hye-Jin   F  29.0   158.0    50.0  South Korea
# 10150     5561         Nickel Ashmeade   M  26.0   183.0    77.0      Jamaica
# 242984  122548  Josua Tuisova Ratulevu   M  22.0   180.0   108.0         Fiji
# 243000  122556              Blair Tuke   M  27.0   181.0    78.0  New Zealand
#
#         noc        games  year  season            city         sport  \
# 38164   KOR  2016 Summer  2016  Summer  Rio de Janeiro       Archery
# 38165   KOR  2016 Summer  2016  Summer  Rio de Janeiro       Archery
# 10150   JAM  2016 Summer  2016  Summer  Rio de Janeiro     Athletics
# 242984  FIJ  2016 Summer  2016  Summer  Rio de Janeiro  Rugby Sevens
# 243000  NZL  2016 Summer  2016  Summer  Rio de Janeiro       Sailing
#
#                                        event medal       region notes
# 38164             Archery Women's Individual  Gold  South Korea   NaN
# 38165                   Archery Women's Team  Gold  South Korea   NaN
# 10150   Athletics Men's 4 x 100 metres Relay  Gold      Jamaica   NaN
# 242984       Rugby Sevens Men's Rugby Sevens  Gold         Fiji   NaN
# 243000                   Sailing Men's Skiff  Gold  New Zealand   NaN

# %%
gold_medalists.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13366 entries, 38164 to 69539
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      13366 non-null  int64
#  1   name    13366 non-null  object
#  2   sex     13366 non-null  category
#  3   age     13366 non-null  float64
#  4   height  13366 non-null  float64
#  5   weight  13366 non-null  float64
#  6   team    13366 non-null  category
#  7   noc     13366 non-null  category
#  8   games   13366 non-null  category
#  9   year    13366 non-null  int32
#  10  season  13366 non-null  category
#  11  city    13366 non-null  object
#  12  sport   13366 non-null  object
#  13  event   13366 non-null  category
#  14  medal   13366 non-null  category
#  15  region  13365 non-null  object
#  16  notes   171 non-null    object
# dtypes: category(7), float64(3), int32(1), int64(1), object(5)
# memory usage: 1.8+ MB

# %% [markdown]
# Here, I have got more than 13k rows. I only wanna get columns containig values.

# %%
new_gold_mdls = gold_medalists[(gold_medalists['height'].notnull()) & (gold_medalists['weight'].notnull())]

# %%
new_gold_mdls.isnull().any()
# Out:
# id        False
# name      False
# sex       False
# age       False
# height    False
# weight    False
# team      False
# noc       False
# games     False
# year      False
# season    False
# city      False
# sport     False
# event     False
# medal     False
# region     True
# notes      True
# dtype: bool

# %%
new_gold_mdls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13366 entries, 38164 to 69539
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      13366 non-null  int64
#  1   name    13366 non-null  object
#  2   sex     13366 non-null  category
#  3   age     13366 non-null  float64
#  4   height  13366 non-null  float64
#  5   weight  13366 non-null  float64
#  6   team    13366 non-null  category
#  7   noc     13366 non-null  category
#  8   games   13366 non-null  category
#  9   year    13366 non-null  int32
#  10  season  13366 non-null  category
#  11  city    13366 non-null  object
#  12  sport   13366 non-null  object
#  13  event   13366 non-null  category
#  14  medal   13366 non-null  category
#  15  region  13365 non-null  object
#  16  notes   171 non-null    object
# dtypes: category(7), float64(3), int32(1), int64(1), object(5)
# memory usage: 1.3+ MB

# %% [markdown]
# Now I have just above 10k columns, I need to create a scatterplot next to visualize relationships

# %%
plt.figure(figsize=(12, 10))
ax = sns.scatterplot(x="height", y="weight", data=new_gold_mdls)
plt.title('Height vs Weight of Gold Medalists')
# Out:
# Text(0.5, 1.0, 'Height vs Weight of Gold Medalists')

# %% [markdown]
# The majority of dots represents a linear relatioship between height and weight. As the hight increases weight also increases.

# %% [markdown]
# I just wanna see the number of athletes with more than 150kg weight

# %%
over_weight = new_gold_mdls.loc[new_gold_mdls['weight'] > 150]
over_weight
# Out:
#             id                           name sex   age  height  weight  \
# 233745  118074               Lasha Talakhadze   M  22.0   197.0   160.0
# 207047  104740       Behdad Salimi Kordasiabi   M  22.0   192.0   160.0
# 198117  100282             Hossein Reza Zadeh   M  26.0   185.0   155.0
# 198116  100282             Hossein Reza Zadeh   M  22.0   185.0   155.0
# 38909    20144     Andrey Ivanovich Chemerkin   M  24.0   183.0   170.0
# 4400      2511     Vasily Ivanovich Alekseyev   M  34.0   185.0   160.0
# 4399      2511     Vasily Ivanovich Alekseyev   M  30.0   185.0   160.0
# 266673  134407  Leonid Ivanovych Zhabotynskiy   M  30.0   189.0   163.0
# 266672  134407  Leonid Ivanovych Zhabotynskiy   M  26.0   189.0   163.0
#
#                 team  noc        games  year  season            city  \
# 233745       Georgia  GEO  2016 Summer  2016  Summer  Rio de Janeiro
# 207047          Iran  IRI  2012 Summer  2012  Summer          London
# 198117          Iran  IRI  2004 Summer  2004  Summer          Athina
# 198116          Iran  IRI  2000 Summer  2000  Summer          Sydney
# 38909         Russia  RUS  1996 Summer  1996  Summer         Atlanta
# 4400    Soviet Union  URS  1976 Summer  1976  Summer        Montreal
# 4399    Soviet Union  URS  1972 Summer  1972  Summer          Munich
# 266673  Soviet Union  URS  1968 Summer  1968  Summer     Mexico City
# 266672  Soviet Union  URS  1964 Summer  1964  Summer           Tokyo
#
#                 sport                                  event medal   region  \
# 233745  Weightlifting  Weightlifting Men's Super-Heavyweight  Gold  Georgia
# 207047  Weightlifting  Weightlifting Men's Super-Heavyweight  Gold     Iran
# 198117  Weightlifting  Weightlifting Men's Super-Heavyweight  Gold     Iran
# 198116  Weightlifting  Weightlifting Men's Super-Heavyweight  Gold     Iran
# 38909   Weightlifting  Weightlifting Men's Super-Heavyweight  Gold   Russia
# 4400    Weightlifting  Weightlifting Men's Super-Heavyweight  Gold   Russia
# 4399    Weightlifting  Weightlifting Men's Super-Heavyweight  Gold   Russia
# 266673  Weightlifting        Weightlifting Men's Heavyweight  Gold   Russia
# 266672  Weightlifting        Weightlifting Men's Heavyweight  Gold   Russia
#
#        notes
# 233745   NaN
# 207047   NaN
# 198117   NaN
# 198116   NaN
# 38909    NaN
# 4400     NaN
# 4399     NaN
# 266673   NaN
# 266672   NaN

# %%
over_weight['id'].count()
# Out:
# 9

# %% [markdown]
# Only 9 Athletes are above 150KG, That's quite interesting as well. I am moving forward with further analysis to know more

# %% [markdown]
# ### Let's study the Age, Height & Weight relatioship with Medal Winning's

# %% [markdown]
# I am only taking medal winners of United States as they got the highest number of medals in the history of olympics. to get more accurate outcome, also It is the ultimate goal of this research to get the best possible outcomes.
#
# Moreover I am not comparing sex and win in this part as Olympics has seperate competitions for Male and Female. So no point in studying winning chance based on sex.

# %%
data.head()
# Out:
#            id                              name sex   age  height  weight  \
# 194731  98525          Maksim Sergeyevich Rakov   M  30.0   181.0   100.0
# 162035  82008  Alexandra Patricia "Alex" Morgan   F  27.0   173.0    62.0
# 117646  59981                    Kim Hyeon-Seop   M  31.0   175.0    53.0
# 117647  59981                    Kim Hyeon-Seop   M  31.0   175.0    53.0
# 38150   19756                         Chang Hao   M  25.0   173.0    72.0
#
#                   team  noc        games  year  season            city  \
# 194731      Kazakhstan  KAZ  2016 Summer  2016  Summer  Rio de Janeiro
# 162035   United States  USA  2016 Summer  2016  Summer  Rio de Janeiro
# 117646     South Korea  KOR  2016 Summer  2016  Summer  Rio de Janeiro
# 117647     South Korea  KOR  2016 Summer  2016  Summer  Rio de Janeiro
# 38150   Chinese Taipei  TPE  2016 Summer  2016  Summer  Rio de Janeiro
#
#             sport                               event medal       region notes
# 194731       Judo         Judo Men's Half-Heavyweight   NaN   Kazakhstan   NaN
# 162035   Football           Football Women's Football   NaN          USA   NaN
# 117646  Athletics  Athletics Men's 20 kilometres Walk   NaN  South Korea   NaN
# 117647  Athletics  Athletics Men's 50 kilometres Walk   NaN  South Korea   NaN
# 38150     Sailing            Sailing Men's Windsurfer   NaN       Taiwan   NaN

# %%
#us_data = data[(data.team == 'United States')]
us_data = data
us_data.tail()
# Out:
#            id                        name sex   age      height     weight  \
# 96389   49185               Fritz Hofmann   M  24.0  167.000000  56.000000
# 96390   49185               Fritz Hofmann   M  24.0  167.000000  56.000000
# 54562   28169          Georgios Diamantis   M  24.0  175.338941  70.701618
# 135986  68911    Albin Georges Lermusiaux   M  21.0  175.338941  70.701618
# 69539   35698  Edwin Harold "Teddy" Flack   M  22.0  175.338941  70.701618
#
#              team  noc        games  year  season    city      sport  \
# 96389     Germany  GER  1896 Summer  1896  Summer  Athina  Athletics
# 96390     Germany  GER  1896 Summer  1896  Summer  Athina  Athletics
# 54562      Greece  GRE  1896 Summer  1896  Summer  Athina   Shooting
# 135986     France  FRA  1896 Summer  1896  Summer  Athina  Athletics
# 69539   Australia  AUS  1896 Summer  1896  Summer  Athina  Athletics
#
#                                             event medal     region notes
# 96389                 Athletics Men's Triple Jump   NaN    Germany   NaN
# 96390                    Athletics Men's Shot Put   NaN    Germany   NaN
# 54562   Shooting Men's Military Rifle, 200 metres   NaN     Greece   NaN
# 135986                   Athletics Men's Marathon   NaN     France   NaN
# 69539                Athletics Men's 1,500 metres  Gold  Australia   NaN

# %%
us_data = us_data.sort_values('year', ascending=False).drop_duplicates(subset=['year', 'sport'])

# %%
#us_data = us_data[us_data.medal.notnull()]

# %%
us_data.head()
# Out:
#             id                           name sex   age  height  weight  \
# 194731   98525       Maksim Sergeyevich Rakov   M  30.0   181.0   100.0
# 67487    34748     David Rubn Sousa Fernandes   M  32.0   181.0    82.0
# 198600  100515         Jonelle Richards-Price   F  35.0   162.0    57.0
# 67483    34745  Bruno Miguel Borges Fernandes   M  21.0   182.0    80.0
# 79381    40611                   Niccol Gitto   M  29.0   190.0    90.0
#
#                team  noc        games  year  season            city  \
# 194731   Kazakhstan  KAZ  2016 Summer  2016  Summer  Rio de Janeiro
# 67487      Portugal  POR  2016 Summer  2016  Summer  Rio de Janeiro
# 198600  New Zealand  NZL  2016 Summer  2016  Summer  Rio de Janeiro
# 67483      Portugal  POR  2016 Summer  2016  Summer  Rio de Janeiro
# 79381         Italy  ITA  2016 Summer  2016  Summer  Rio de Janeiro
#
#                 sport                                      event   medal  \
# 194731           Judo                Judo Men's Half-Heavyweight     NaN
# 67487        Canoeing   Canoeing Men's Kayak Fours, 1,000 metres     NaN
# 198600  Equestrianism  Equestrianism Mixed Three-Day Event, Team     NaN
# 67483        Football                    Football Men's Football     NaN
# 79381      Water Polo                Water Polo Men's Water Polo  Bronze
#
#              region notes
# 194731   Kazakhstan   NaN
# 67487      Portugal   NaN
# 198600  New Zealand   NaN
# 67483      Portugal   NaN
# 79381         Italy   NaN

# %% [markdown]
# I need to filter only few variables which are required for my core study, like Height, Weight, Age, Sex. In this study I wanna consider all the three medals as a win for more efficient analysis.

# %%
#us_data.loc["sex", "height", "weight", "medal"]
columns = ['year','season','sex', 'age', 'height', 'weight','team','event','medal','games','sport']
us_data = pd.DataFrame(us_data, columns=columns)
us_data.tail()
# Out:
#         year  season sex   age      height     weight     team  \
# 183735  1896  Summer   M  24.0  175.338941  70.701618   Greece
# 111156  1896  Summer   M  24.0  175.338941  70.701618  Hungary
# 36266   1896  Summer   M  23.0  175.338941  70.701618   Greece
# 212743  1896  Summer   M  26.0  159.000000  70.000000  Germany
# 250060  1896  Summer   M  24.0  175.338941  70.701618   Greece
#
#                                                event   medal        games  \
# 183735           Swimming Men's 500 metres Freestyle  Silver  1896 Summer
# 111156               Gymnastics Men's Horizontal Bar     NaN  1896 Summer
# 36266                           Tennis Men's Singles  Silver  1896 Summer
# 212743  Wrestling Men's Unlimited Class, Greco-Roman    Gold  1896 Summer
# 250060       Weightlifting Men's Unlimited, One Hand     NaN  1896 Summer
#
#                 sport
# 183735       Swimming
# 111156     Gymnastics
# 36266          Tennis
# 212743      Wrestling
# 250060  Weightlifting

# %%
us_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 906 entries, 194731 to 250060
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    906 non-null    int32
#  1   season  906 non-null    category
#  2   sex     906 non-null    category
#  3   age     906 non-null    float64
#  4   height  906 non-null    float64
#  5   weight  906 non-null    float64
#  6   team    906 non-null    category
#  7   event   906 non-null    category
#  8   medal   180 non-null    category
#  9   games   906 non-null    category
#  10  sport   906 non-null    object
# dtypes: category(6), float64(3), int32(1), object(1)
# memory usage: 112.4+ KB

# %%
us_data['win'] = us_data['medal'].notnull()*1
us_data['win'] 
us_data.tail(10)
# Out:
#         year  season sex   age      height     weight     team  \
# 49932   1900  Summer   M  26.0  175.338941  70.701618    Spain
# 182196  1896  Summer   M  24.0  175.338941  70.701618   Greece
# 211506  1896  Summer   M  23.0  175.338941  70.701618  Austria
# 80415   1896  Summer   M  21.0  175.338941  70.701618   Greece
# 211505  1896  Summer   M  23.0  175.338941  70.701618  Austria
# 183735  1896  Summer   M  24.0  175.338941  70.701618   Greece
# 111156  1896  Summer   M  24.0  175.338941  70.701618  Hungary
# 36266   1896  Summer   M  23.0  175.338941  70.701618   Greece
# 212743  1896  Summer   M  26.0  159.000000  70.000000  Germany
# 250060  1896  Summer   M  24.0  175.338941  70.701618   Greece
#
#                                                event   medal        games  \
# 49932   Basque Pelota Men's Two-Man Teams With Cesta    Gold  1900 Summer
# 182196     Shooting Men's Military Rifle, 200 metres  Silver  1896 Summer
# 211506               Fencing Men's Sabre, Individual     NaN  1896 Summer
# 80415                   Athletics Men's 1,500 metres     NaN  1896 Summer
# 211505           Cycling Men's 333 metres Time Trial  Bronze  1896 Summer
# 183735           Swimming Men's 500 metres Freestyle  Silver  1896 Summer
# 111156               Gymnastics Men's Horizontal Bar     NaN  1896 Summer
# 36266                           Tennis Men's Singles  Silver  1896 Summer
# 212743  Wrestling Men's Unlimited Class, Greco-Roman    Gold  1896 Summer
# 250060       Weightlifting Men's Unlimited, One Hand     NaN  1896 Summer
#
#                 sport  win
# 49932   Basque Pelota    1
# 182196       Shooting    1
# 211506        Fencing    0
# 80415       Athletics    0
# 211505        Cycling    1
# 183735       Swimming    1
# 111156     Gymnastics    0
# 36266          Tennis    1
# 212743      Wrestling    1
# 250060  Weightlifting    0

# %%
#us_data['medal'] = us_data['medal'].astype('str')
#us_data['medal'] = us_data['medal'].replace(np.nan, 0)
#us_data['medal'] = us_data['medal'].astype('category')
#us_data.tail()

# %%
us_data['win'] = us_data['win'].astype('int')
us_data['medal'] = us_data['medal'].astype('category')
#us_data['medal'] = us_data['medal'].astype('str')
us_data.dtypes
# Out:
# year         int32
# season    category
# sex       category
# age        float64
# height     float64
# weight     float64
# team      category
# event     category
# medal     category
# games     category
# sport       object
# win          int32
# dtype: object

# %% [markdown]
# ##### Comparing between season and sex

# %%
sns.countplot(x='season',hue='sex',data=us_data)
plt.show()

# %% [markdown]
# Best way to check 2 categorical varible is to make cross tab. seems to be there is no much relationship going on between season and sex.

# %%
sex_season = pd.crosstab(index=us_data['sex'], columns=us_data["season"],
margins=True)
sex_season
# Out:
# season  Summer  Winter  All
# sex
# F          136      51  187
# M          536     183  719
# All        672     234  906

# %% [markdown]
# ##### Comparing between season and age

# %%
sns.boxplot(x='age',y='season',data=us_data)
plt.show()

# %% [markdown]
# Medians are almost same and IQR's are completely overlapping. no much relation going on

# %%
sns.boxplot(x="win",y="age", data=us_data)
plt.show()

# %% [markdown]
# The median age for win is more that median age of no-win. Also IQR's are not completely overlapping. I think there must be a relation between age and win

# %%
sns.boxplot(x="win",y="height", data=us_data)
plt.show()

# %% [markdown]
# Again the median for win and no win seems to be almost equal. And the IQR is completely overlapping. Could not find any relation going on here, also it seems to have most winnings lies between 168 to 184 Height.

# %%
sns.boxplot(x="win",y="weight", data=us_data)
plt.show()

# %% [markdown]
# Between Sex and Win , There is no much relatioship going on here. As both counts are showing equal proportions.

# %%
sns.countplot(x='season',hue='win',data=us_data)
plt.show()

# %% [markdown]
# Between Seaon and Win , There is no much relatioship going on here. As both counts are showing equal proportions.

# %%
sns.countplot(x='sex',hue='win',data=us_data)
plt.show()

# %%
sns.lmplot(x='height',y='age',hue='win',data=us_data,fit_reg=False)
plt.show()

# %%
us_data = pd.DataFrame(us_data)
rank = us_data['medal'] 
us_data['rank'] = rank
us_data['rank'] = us_data['rank'].replace(['Gold','Silver','Bronze'], [1, 2, 3])

# %%
us_data['rank'] = us_data['rank'].replace('?', np.NaN)

us_data['games'] = us_data['games'].astype('str')

# %%
us_data['rank'].head()
# Out:
# 194731    NaN
# 67487     NaN
# 198600    NaN
# 67483     NaN
# 79381     3.0
# Name: rank, dtype: float64

# %%
us_data.dtypes
# Out:
# year         int32
# season    category
# sex       category
# age        float64
# height     float64
# weight     float64
# team      category
# event     category
# medal     category
# games       object
# sport       object
# win          int32
# rank       float64
# dtype: object

# %%
us_data.head(15)
# Out:
#         year  season sex   age  height  weight           team  \
# 194731  2016  Summer   M  30.0   181.0   100.0     Kazakhstan
# 67487   2016  Summer   M  32.0   181.0    82.0       Portugal
# 198600  2016  Summer   F  35.0   162.0    57.0    New Zealand
# 67483   2016  Summer   M  21.0   182.0    80.0       Portugal
# 79381   2016  Summer   M  29.0   190.0    90.0          Italy
# 79395   2016  Summer   M  25.0   185.0    82.0         Canada
# 25775   2016  Summer   M  28.0   180.0    67.0        Belgium
# 189295  2016  Summer   F  21.0   163.0    55.0          Italy
# 189365  2016  Summer   F  30.0   180.0    84.0  United States
# 28742   2016  Summer   M  26.0   167.0    60.0        Germany
# 198427  2016  Summer   M  33.0   173.0    94.0      Australia
# 67546   2016  Summer   M  33.0   180.0   115.0          Spain
# 197521  2016  Summer   M  19.0   202.0    90.0           Cuba
# 191011  2016  Summer   F  28.0   173.0    70.0    New Zealand
# 265554  2016  Summer   M  25.0   186.0    80.0      Australia
#
#                                             event   medal        games  \
# 194731                Judo Men's Half-Heavyweight     NaN  2016 Summer
# 67487    Canoeing Men's Kayak Fours, 1,000 metres     NaN  2016 Summer
# 198600  Equestrianism Mixed Three-Day Event, Team     NaN  2016 Summer
# 67483                     Football Men's Football     NaN  2016 Summer
# 79381                 Water Polo Men's Water Polo  Bronze  2016 Summer
# 79395                     Badminton Men's Singles     NaN  2016 Summer
# 25775        Athletics Men's 4 x 400 metres Relay     NaN  2016 Summer
# 189295      Swimming Women's 200 metres Butterfly     NaN  2016 Summer
# 189365                Rowing Women's Coxed Eights    Gold  2016 Summer
# 28742      Gymnastics Men's Individual All-Around     NaN  2016 Summer
# 198427     Weightlifting Men's Middle-Heavyweight     NaN  2016 Summer
# 67546                         Shooting Men's Trap     NaN  2016 Summer
# 197521                Volleyball Men's Volleyball     NaN  2016 Summer
# 191011          Sailing Women's Two Person Dinghy  Silver  2016 Summer
# 265554                        Hockey Men's Hockey     NaN  2016 Summer
#
#                 sport  win  rank
# 194731           Judo    0   NaN
# 67487        Canoeing    0   NaN
# 198600  Equestrianism    0   NaN
# 67483        Football    0   NaN
# 79381      Water Polo    1   3.0
# 79395       Badminton    0   NaN
# 25775       Athletics    0   NaN
# 189295       Swimming    0   NaN
# 189365         Rowing    1   1.0
# 28742      Gymnastics    0   NaN
# 198427  Weightlifting    0   NaN
# 67546        Shooting    0   NaN
# 197521     Volleyball    0   NaN
# 191011        Sailing    1   2.0
# 265554         Hockey    0   NaN

# %%
us_data.dtypes
# Out:
# year         int32
# season    category
# sex       category
# age        float64
# height     float64
# weight     float64
# team      category
# event     category
# medal     category
# games       object
# sport       object
# win          int32
# rank       float64
# dtype: object

# %%
us_data['rank'].isnull().sum().sum()
# Out:
# 726

# %% [markdown]
# <div style="background-color:#e8ca66; padding-left: 12px !important;"><br><b>Logistic Regression</b><br><br>
# As previously mentioned, my response variable is win . <i>My research Question is what Influences the chances of getting a medal in Olympics</i>
# <br><br>

# %% [markdown]
# As I already made graphs above between different variables, I can refer them to decide between their replationship

# %%
sns.scatterplot(x='year',y='age',hue='sex',data=us_data)
plt.show()

# %%
from statsmodels.formula.api import logit
logit_model=logit('win~ age+height+weight+ C(season)',us_data).fit()
logit_model.summary2()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.491222
#          Iterations 6
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                           Results: Logit
# ===================================================================
# Model:               Logit             Pseudo R-squared:  0.015
# Dependent Variable:  win               AIC:               900.0937
# Date:                2021-12-09 23:15  BIC:               924.1389
# No. Observations:    906               Log-Likelihood:    -445.05
# Df Model:            4                 LL-Null:           -451.70
# Df Residuals:        901               LLR p-value:       0.0099058
# Converged:           1.0000            Scale:             1.0000
# No. Iterations:      6.0000
# -------------------------------------------------------------------
#                      Coef.  Std.Err.    z    P>|z|   [0.025  0.975]
# -------------------------------------------------------------------
# Intercept           -0.0807   2.3902 -0.0338 0.9731 -4.7654  4.6040
# C(season)[T.Winter] -0.6559   0.2175 -3.0161 0.0026 -1.0821 -0.2297
# age                  0.0185   0.0135  1.3756 0.1689 -0.0079  0.0450
# height              -0.0086   0.0168 -0.5114 0.6091 -0.0416  0.0244
# weight              -0.0020   0.0119 -0.1669 0.8675 -0.0252  0.0213
# ===================================================================
#
# """

# %% [markdown]
# <b>I am trying to predict probability of win </b>

# %% [markdown]
# I have removed sex from this regression as there is seperate competitions for male and female. Olympics is not a unisex competition, so no sense on testing it's probability.

# %% [markdown]
# <i>pi here is probability of win</i>
#
# logit(pi)=log(success odd of win) = log (pi/(1-pi)) = -0.0807 - 0.6559 winterseason + 0.0185 age - 0.0086 height - 0.0020 weight
#
# Intercept - everything else is zero Probability of success

# %%
np.exp(-0.0807)
# Out:
# 0.9224703910549078

# %% [markdown]
# Estimated success odds for win 0.922 in summer season from a team with 0 age with 0 height and 0 weight

# %%
np.exp(-0.6559)
# Out:
# 0.5189747750416571

# %% [markdown]
# Estimated success odds for win change by factor of 0.518 when you change from summer to winter with 0 age with 0 height and 0 weight

# %%
np.exp(0.0185)
# Out:
# 1.018672185169575

# %% [markdown]
# Estimated success odds for win change by factor of 1.018 when change age change by 1 in summer/winter with 0 height and 0 weight

# %%
np.exp(-0.0086)
# Out:
# 0.9914368742181953

# %% [markdown]
# Estimated success odds for win change by factor of 0.991 when you change height by 1 unit in winter/summer with 0 age and 0 weight

# %%
np.exp(-0.0020)
# Out:
# 0.9980019986673331

# %% [markdown]
# Estimated success odds for win change by factor of 0.998 when you change weight by 1 unit in winter/summer with 0 age and 0 height

# %% [markdown]
# <div style="color:#102547; background-color:powderblue; padding-left: 12px !important;"><br><b>conclusion</b>
#
# All terms are significantly different 0 (i.e. they do not have a relationship with win) bar season (p=0.0026<0.05) LRT
#
# comparing to null model, p-value = 0.0099058 < 0.05 so reject H0 that the Null model is preferred <br><br></div>

# %% [markdown]
# We were testing the Null Hypothesis H0, so even when we take the exponensial

# %%
sns.lmplot(x='age', y='height', hue="win",data=us_data,fit_reg=False)
plt.show()

# %% [markdown]
# <div style="background-color:#e8ca66; padding-left: 12px !important;"><br><b>Hypothesis</b>
#
# H0: There is no significant relation between athletes with age of 35 or more/less and win
#
# H1: There is significant relation between athletes with age of 35 or more/less and win
# <br><br></div>

# %%
old_win = us_data[us_data['age'] > 35 ]['win']
young_win = us_data[us_data['age'] < 35 ]['win']

# %% [markdown]
# ##### Ranksum Test

# %% [markdown]
# <div style="color:#102547; background-color:powderblue; padding-left: 12px !important;"><br><b>Conclusion of Age and Win relatioship</b>
#
# As per the <b>P Value - 0.62</b> which I got from the Ranksum Test is <b>greater than 0.05</b>, So we can reject the Null Hypothesis.
#
# We can say there is a significant relation between athletes with age of 35 or more/less and win. It is proved in the above test. <br> <br> </div>

# %%
from scipy.stats import ranksums
ranksums(old_win,young_win)
# Out:
# RanksumsResult(statistic=0.48694673646368175, pvalue=0.6262960773090279)

# %% [markdown]
# <div style="background-color:#e8ca66; padding-left: 12px !important;"><br><b>Hypothesis</b>
#
# H0: There is no significant relation between Height and win
#
# H1: There is significant relation between Height and win
# <br><br></div>

# %%
tall_win = us_data[us_data['height'] > 150 ]['win']
short_win = us_data[us_data['height'] == 150 ]['win']

# %% [markdown]
# ##### Ranksum Test

# %%
from scipy.stats import ranksums
ranksums(tall_win,short_win)
# Out:
# RanksumsResult(statistic=-1.3890902696789948, pvalue=0.16480530221911405)

# %% [markdown]
# <div style="color:#102547; background-color:powderblue; padding-left: 12px !important;"><br><b>Conclusion of Weight and Win relationship</b>
#
# As per the <b>P Value = 0.16</b> which I got from the Ranksum Test is <b>greater than 0.05</b>, So I can reject the Null Hypothesis.
#
# We can say there is a significant relation between Height and win. It is proved in the above test. <br> <br> </div>

# %% [markdown]
# <div style="background-color:#e8ca66; padding-left: 12px !important;"><br><b>Hypothesis</b>
#
# H0: There is no significant relation between Weight and win
#
# H1: There is significant relation between Weight and win
# <br><br></div>

# %% [markdown]
# ##### Ranksum Test

# %%
ok_w = us_data[us_data['weight'] <60]['win']
nok_w = us_data[us_data['weight'] >60]['win']

# %%
from scipy.stats import ranksums
ranksums(ok_w,nok_w)
# Out:
# RanksumsResult(statistic=-0.10148076190990243, pvalue=0.9191688284845534)

# %% [markdown]
# <div style="color:#102547; background-color:powderblue; padding-left: 12px !important;"><br><b>Conclusion of Weight and Win relationship</b>
#
# As per the <b>P Value = 0.91</b> which I got from the Ranksum Test is <b>greater than 0.05</b>, So I can reject the Null Hypothesis.
#
# We can say there is a significant relation between Weight and win. It is proved in the above test. <br> <br> </div>

# %%
us_data['win'] = us_data['win'].astype('category')

# %% [markdown]
# I am considering 1 as win and 0 as no win, this variable is created from medal columns and used yes or no logic for converting if there is a value present then change it to 'one' if not 'zero'.

# %% [markdown]
# During my test , I could not see any significant linear relaion between age, height ,weight and win. So I am now going to look  deeper into hight jump win and age,height, weight.

# %% [markdown]
# ##### Test on Wrestling

# %%
wre_data = us_data[(us_data.sport == "Wrestling")]

# %%
wre_data = wre_data.reset_index(drop=True)

# %%
wre_data.head()
# Out:
#    year  season sex   age  height  weight        team  \
# 0  2016  Summer   M  22.0   165.0    86.0       Egypt
# 1  2012  Summer   F  31.0   155.0    53.0     Senegal
# 2  2008  Summer   M  27.0   178.0    74.0     Algeria
# 3  2004  Summer   F  36.0   162.0    48.0  Tajikistan
# 4  2000  Summer   M  26.0   170.0    69.0       Japan
#
#                                           event   medal        games  \
# 0  Wrestling Men's Light-Heavyweight, Freestyle     NaN  2016 Summer
# 1        Wrestling Women's Flyweight, Freestyle     NaN  2012 Summer
# 2     Wrestling Men's Middleweight, Greco-Roman     NaN  2008 Summer
# 3        Wrestling Women's Flyweight, Freestyle     NaN  2004 Summer
# 4     Wrestling Men's Welterweight, Greco-Roman  Silver  2000 Summer
#
#        sport win  rank
# 0  Wrestling   0   NaN
# 1  Wrestling   0   NaN
# 2  Wrestling   0   NaN
# 3  Wrestling   0   NaN
# 4  Wrestling   1   2.0

# %% [markdown]
# <div style="background-color:#e8ca66; padding-left: 12px !important;"><br><b>Hypothesis</b>
#
# H0: There is no significant relation between Height and win
#
# H1: There is significant relation between Height and win
# <br><br></div>

# %%
chi2_contingency = pd.crosstab(index = wre_data['win'],columns=wre_data['height'], margins= True)
chi2_contingency
# Out:
# height  149.0  155.0  159.0  162.0  163.0  165.0  166.0  167.0  168.0  170.0  \
# win
# 0           1      1      0      1      0      1      2      1      1      1
# 1           0      0      2      0      1      0      0      1      0      1
# All         1      1      2      1      1      1      2      2      1      2
#
# height  175.33894093995372  178.0  180.0  192.0  All
# win
# 0                        9      1      1      1   21
# 1                        2      0      0      0    7
# All                     11      1      1      1   28

# %%
from scipy.stats import chi2_contingency
chi2_contingency(pd.crosstab(index=wre_data['win'], columns=wre_data["height"]))
# Out:
# (13.93939393939394,
#  0.37812598765008776,
#  13,
#  array([[0.75, 0.75, 1.5 , 0.75, 0.75, 0.75, 1.5 , 1.5 , 0.75, 1.5 , 8.25,
#          0.75, 0.75, 0.75],
#         [0.25, 0.25, 0.5 , 0.25, 0.25, 0.25, 0.5 , 0.5 , 0.25, 0.5 , 2.75,
#          0.25, 0.25, 0.25]]))

# %% [markdown]
# <div style="color:#102547; background-color:powderblue; padding-left: 12px !important;"><br><br><b>Conclusion of Weight and Win relationship</b><br><br>pvalue = 0.378 > 0.05 there is a relation between height and win<br><br></div>

# %%
bskt_data = us_data[(us_data.sport == "Basketball")]

# %%
bskt_data = bskt_data.reset_index(drop=True)

# %%
bskt_data.head()
# Out:
#         year  season sex   age  height  weight         team  \
# 68487   2016  Summer   F  22.0   170.0    57.0       Canada
# 230511  2012  Summer   M  26.0   206.0    95.0        China
# 1863    2008  Summer   F  29.0   170.0    65.0       Brazil
# 245644  2004  Summer   F  27.0   181.0    78.0        Spain
# 148768  2000  Summer   M  25.0   208.0   115.0  New Zealand
#
#                                 event medal        games       sport win  rank
# 68487   Basketball Women's Basketball   NaN  2016 Summer  Basketball   0   NaN
# 230511    Basketball Men's Basketball   NaN  2012 Summer  Basketball   0   NaN
# 1863    Basketball Women's Basketball   NaN  2008 Summer  Basketball   0   NaN
# 245644  Basketball Women's Basketball   NaN  2004 Summer  Basketball   0   NaN
# 148768    Basketball Men's Basketball   NaN  2000 Summer  Basketball   0   NaN

# %% [markdown]
# <div style="background-color:#e8ca66; padding-left: 12px !important;"><br><b>Hypothesis</b>
#
# H0: There is no significant relation between Height and win
#
# H1: There is significant relation between Height and win
# <br><br></div>

# %%
chi2_contingency = pd.crosstab(index = bskt_data['win'],columns=bskt_data['height'], margins= True)
chi2_contingency
# Out:
# height  170.0  175.0  175.33894093995372  179.0  181.0  187.0  188.0  189.0  \
# win
# 0           2      1                   3      1      1      1      1      0
# 1           0      1                   0      0      0      0      0      1
# All         2      2                   3      1      1      1      1      1
#
# height  190.0  200.0  206.0  208.0  210.0  All
# win
# 0           1      1      1      2      0   15
# 1           0      0      0      1      1    4
# All         1      1      1      3      1   19

# %%
from scipy.stats import chi2_contingency
chi2_contingency(pd.crosstab(index=bskt_data['win'], columns=bskt_data["height"]))
# Out:
# (11.980555555555558,
#  0.44724251769223977,
#  12,
#  array([[1.57894737, 1.57894737, 2.36842105, 0.78947368, 0.78947368,
#          0.78947368, 0.78947368, 0.78947368, 0.78947368, 0.78947368,
#          0.78947368, 2.36842105, 0.78947368],
#         [0.42105263, 0.42105263, 0.63157895, 0.21052632, 0.21052632,
#          0.21052632, 0.21052632, 0.21052632, 0.21052632, 0.21052632,
#          0.21052632, 0.63157895, 0.21052632]]))

# %% [markdown]
# <div style="color:#102547; background-color:powderblue; padding-left: 12px !important;"><br><br><b>Conclusion of Weight and Win relationship</b><br><br>pvalue = 0.0.447 > 0.05 there is a relation between height and win<br><br></div>

# %% [markdown]
# #### Bokeh Plot for more interactive analysis

# %%
# output to static HTML file
output_file("us_olympics_data_output.html")
# NEW: create a column data source for the plots to share
source = ColumnDataSource(data=dict(x1=us_data.height[us_data.win == 1], x2=us_data.height[us_data.win ==0 ], y = us_data['age']))
TOOLS = "pan,wheel_zoom,box_zoom,reset,save,box_select,lasso_select"
# create a new plot and add a renderer
left = figure(tools=TOOLS, width=550, height=550)
left.circle('x1', 'y', source=source)
# configure visual properties on a plot's title attribute
left.title.text = "Olympics age,height and win"
left.title.align = "right"
left.title.text_color = "#b8660f"
left.title.text_font_size = "25px"
left.title.background_fill_color = "#fff"
left.xaxis.axis_label = 'height'
left.yaxis.axis_label = 'age'

# put the subplots in a gridplot
p = gridplot([[left]])

# show the results
show(p)
# Out:
# BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x1', 180), ('x2', 726), ('y', 906)

# %% [markdown]
# Based on the above graph we can see there is only one relationship is seen between height and weight. what we are trying to find in this study is the medal winning

# %% [markdown]
# My response variable is Medal Winning as we are trying to find out is there any relatioship between height, weight & age with medal winnings which I already know and what is difficult to find is the winning of a medal

# %% [markdown]
# <p style="color: green;">As per the above graph It's visible the median is different for win and loss, also there is no overlap. I think there is a relationship between weight and win.</p>

# %% [markdown]
# ### Evolution of the Olympics over time

# %% [markdown]
# I am here trying to figure out 3 main things
# <ul>
# <li>How Participation of Male/Female Athletes varied over time</li>
# <li>How Men-Women proportion varied over time</li>
# <li>Mean age, Height & Weight varied over time</li>
# </ul>

# %% [markdown]
# ##### Participation of Male Female Athletes

# %%
men_over_time = data[(data.sex == 'M') & (data.season == 'Summer')]
women_over_time = data[(data.sex == 'F') & (data.season == 'Summer')]

# %%
men_over_time.head()
# Out:
#            id                          name sex   age  height  weight  \
# 194731  98525      Maksim Sergeyevich Rakov   M  30.0   181.0   100.0
# 117646  59981                Kim Hyeon-Seop   M  31.0   175.0    53.0
# 117647  59981                Kim Hyeon-Seop   M  31.0   175.0    53.0
# 38150   19756                     Chang Hao   M  25.0   173.0    72.0
# 162028  82005  Nikita Andreyevich Morgachov   M  35.0   196.0    98.0
#
#                   team  noc        games  year  season            city  \
# 194731      Kazakhstan  KAZ  2016 Summer  2016  Summer  Rio de Janeiro
# 117646     South Korea  KOR  2016 Summer  2016  Summer  Rio de Janeiro
# 117647     South Korea  KOR  2016 Summer  2016  Summer  Rio de Janeiro
# 38150   Chinese Taipei  TPE  2016 Summer  2016  Summer  Rio de Janeiro
# 162028          Russia  RUS  2016 Summer  2016  Summer  Rio de Janeiro
#
#             sport                               event medal       region notes
# 194731       Judo         Judo Men's Half-Heavyweight   NaN   Kazakhstan   NaN
# 117646  Athletics  Athletics Men's 20 kilometres Walk   NaN  South Korea   NaN
# 117647  Athletics  Athletics Men's 50 kilometres Walk   NaN  South Korea   NaN
# 38150     Sailing            Sailing Men's Windsurfer   NaN       Taiwan   NaN
# 162028     Rowing          Rowing Men's Coxless Fours   NaN       Russia   NaN

# %% [markdown]
# I will be crearing plot first for Men & women seperate

# %%
part = men_over_time.groupby('year')['sex'].value_counts()
plt.figure(figsize=(20, 10))
part.loc[:,'M'].plot()
plt.title('Variation of Male Athletes over time')
# Out:
# Text(0.5, 1.0, 'Variation of Male Athletes over time')

# %%
part = women_over_time.groupby('year')['sex'].value_counts()
plt.figure(figsize=(20, 10))
part.loc[:,'F'].plot()
plt.title('Variation of Female Athletes over time')
# Out:
# Text(0.5, 1.0, 'Variation of Female Athletes over time')

# %% [markdown]
# ##### Variation of age along time

# %%
plt.figure(figsize=(20, 10))
sns.boxplot('year', 'age', data=men_over_time)
plt.title('Variation of Age for Male Athletes over time')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Variation of Age for Male Athletes over time')

# %% [markdown]
#  <br><b>It's interesting to see the age of some athletes varied between 1924 and 1948. Just wanna see the details of athletes more than 80 Years old <br><br>

# %%
men_over_time.loc[men_over_time['age'] > 80].head(15)
# Out:
#             id                    name sex   age      height     weight  \
# 153571   77710    Robert Tait McKenzie   M  81.0  175.338941  70.701618
# 9345      5146   George Denholm Armour   M  84.0  175.338941  70.701618
# 97303    49663           Winslow Homer   M  96.0  175.338941  70.701618
# 255166  128719  John Quincy Adams Ward   M  97.0  175.338941  70.701618
# 235161  118789            Louis Tauzin   M  81.0  175.338941  70.701618
#
#                  team  noc        games  year  season         city  \
# 153571         Canada  CAN  1948 Summer  1948  Summer       London
# 9345    Great Britain  GBR  1948 Summer  1948  Summer       London
# 97303   United States  USA  1932 Summer  1932  Summer  Los Angeles
# 255166  United States  USA  1928 Summer  1928  Summer    Amsterdam
# 235161         France  FRA  1924 Summer  1924  Summer        Paris
#
#                    sport                                              event  \
# 153571  Art Competitions  Art Competitions Mixed Sculpturing, Unknown Event
# 9345    Art Competitions     Art Competitions Mixed Painting, Unknown Event
# 97303   Art Competitions     Art Competitions Mixed Painting, Unknown Event
# 255166  Art Competitions        Art Competitions Mixed Sculpturing, Statues
# 235161  Art Competitions                 Art Competitions Mixed Sculpturing
#
#        medal  region notes
# 153571   NaN  Canada   NaN
# 9345     NaN      UK   NaN
# 97303    NaN     USA   NaN
# 255166   NaN     USA   NaN
# 235161   NaN  France   NaN

# %% [markdown]
# <div style="color:#102547; background-color:powderblue; padding-left: 12px !important;"><br>As Per the data we have it's clear that the competitions of these older athletes(aged more than 80) were art related. I never knew that art was part of olympics, so I had to do some research.
#
# [From Wikipedia](https://en.wikipedia.org/wiki/Art_competitions_at_the_Summer_Olympics)
#
# Art competitions formed part of the modern Olympic Games during its early years, from 1912 to 1948. The competitions were part of the original intention of the Olympic Movement's founder, Pierre de Frédy, Baron de Coubertin. Medals were awarded for works of art inspired by sport, divided into five categories: architecture, literature, music, painting, and sculpture.
# The juried art competitions were abandoned in 1954 because artists were considered to be professionals, while Olympic athletes were required to be amateurs. Since 1956, the Olympic cultural programme has taken their place.<br><br>

# %% [markdown]
# ##### Variation of Height over time

# %%
plt.figure(figsize=(20, 10))
sns.lineplot('year', 'height', data=men_over_time)
plt.title('Variation of Height for Male Athletes over time')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Variation of Height for Male Athletes over time')

# %%
plt.figure(figsize=(20, 10))
sns.lineplot('year', 'height', data=women_over_time)
plt.title('Female Athletes Height Variation over time')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Female Athletes Height Variation over time')

# %% [markdown]
# It's clear from the data that for both women and men height increased over time.
